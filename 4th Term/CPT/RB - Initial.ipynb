# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rb_dir = 'CPT/rb-datasets/'

# %%
ls CPT/rb-datasets/Lazada MSP Traffic 2020.xlsx
# Out:
# 'BA 2019.csv'                   'FB 2019.xls'  'Lazada MSP Traffic 2020.xlsx'
# 'CPT Sample Data Oct2020.xlsx'  'FB 2020.xls'  'Shopee MSP Traffic 2020.xlsx'

# %%
df_fb2020 = pd.read_excel('CPT/rb-datasets/FB 2020.xls', skiprows=13)

# %%
a = df_fb2020[(df_fb2020['Brand Name'] == 'Enfa') | 
          (df_fb2020['Brand Name'] == 'Lactum') ]

# %%
df_MSP = pd.read_excel('CPT/rb-datasets/Lazada MSP Traffic 2020.xlsx')

# %%
df_MSP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36089 entries, 0 to 36088
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    36089 non-null  object
#  1   Year                     36089 non-null  int64
#  2   Date                     36089 non-null  int64
#  3   Campaign ID              36089 non-null  int64
#  4   Campaign Name            36089 non-null  object
#  5   Funding Type             36089 non-null  object
#  6   Brand ID                 36089 non-null  object
#  7   Brand Name               36089 non-null  object
#  8   Seller ID                36089 non-null  object
#  9   Seller Name              36089 non-null  object
#  10  Channel                  36052 non-null  object
#  11  Site                     36052 non-null  object
#  12  Placement                36052 non-null  object
#  13  Offer ID                 36089 non-null  object
# ...

# %%
a = df_MSP[df_MSP['Brand Name'] == 'Enfagrow'].groupby('Month')['Visits'].sum()

# %%
b = df_MSP[df_MSP['Brand Name'] == 'Lactum'].groupby('Month')['Visits'].sum()

# %%
plt.plot(a, c='red')
plt.plot(b, c='blue', )
plt.show()

# %%
df = pd.read_excel('CPT/rb-datasets/CPT Sample Data Oct2020.xlsx')

# %%
df
# Out:
#      Day of date Channel Country   shop_id                 Shop name  \
# 0     2020-10-01  Lazada       PH     3297      Lazada Retail Lactum
# 1     2020-10-01  Lazada       PH     3297      Lazada Retail Lactum
# 2     2020-10-01  Lazada       PH     3297      Lazada Retail Lactum
# 3     2020-10-01  Lazada       PH     3297      Lazada Retail Lactum
# 4     2020-10-01  Lazada       PH     3297      Lazada Retail Lactum
# ...          ...     ...      ...      ...                       ...
# 5096  2020-10-31  Shopee       PH     3840   Enfagrow Official Store
# 5097  2020-10-31  Shopee       PH     3840   Enfagrow Official Store
# 5098  2020-10-31  Shopee       PH     3840   Enfagrow Official Store
# 5099  2020-10-31  Shopee       PH     3840   Enfagrow Official Store
# 5100  2020-10-31  Shopee       PH     3841   sustagenofficialstoreph
#
#                          SKU  \
# 0     260013061_PH-358536442
# 1     260035300_PH-358552297
# 2     267669546_PH-379343854
# ...

# %%
df.groupby('Day of date')['Sales'].sum().plot()
# Out:
# <AxesSubplot:xlabel='Day of date'>
