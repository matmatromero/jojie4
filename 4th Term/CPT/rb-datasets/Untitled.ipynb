# %%
import pandas as pd

# %%
df = pd.read_excel('FB 2019.xls', skiprows=13)

# %%
df_fb5 = df.head()

# %%
df_fb5.to_excel('df_fb.xlsx', index=False)

# %%
df.
# Out:
#                                            Unnamed: 0  \
# 0                                         Report Name
# 1                                         Report Type
# 2                                              Agency
# 3                                       Creation Date
# 4                                            Currency
# 5                                          Time Range
# 6                                      Custom Metrics
# 7                                  Conversion Metrics
# 8   Show Revenue for each conversion type and conv...
# 9                                    Conversion Types
# 10  Break down channel conversion types for click ...
# 11                                                NaN
# 12                                               Date
# 13                                2019-11-24 00:00:00
# 14                                2019-11-25 00:00:00
# 15                                2019-11-26 00:00:00
# ...
