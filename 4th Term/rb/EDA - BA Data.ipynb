# %%
import pandas as pd
import numpy as np

# %%
df_2019 = pd.read_csv('BA_2019_clean.csv')
df_2020 = pd.read_csv('BA_2020_clean.csv')
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_2020 = df_2020.drop(['row', 'shop_id', 'Country'], axis=1)

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33296 entries, 0 to 33295
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           33296 non-null  object
#  1   channel        33296 non-null  object
#  2   country        33296 non-null  object
#  3   shop_name      33296 non-null  object
#  4   sku            33296 non-null  object
#  5   product_name   33296 non-null  object
#  6   brand          33296 non-null  object
#  7   url            33296 non-null  object
#  8   sap            33296 non-null  float64
#  9   cat1           7102 non-null   object
#  10  cat2           7102 non-null   object
#  11  cat3           7102 non-null   object
#  12  cat4           7102 non-null   object
#  13  cat5           7102 non-null   object
#  14  cat6           7102 non-null   object
#  15  sales          33296 non-null  int64
#  16  units_sold     33296 non-null  int64
# ...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59711 entries, 0 to 59710
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           59711 non-null  object
#  1   channel        59711 non-null  object
#  2   country        45933 non-null  object
#  3   shop_name      59711 non-null  object
#  4   sku            59711 non-null  object
#  5   product_name   59711 non-null  object
#  6   brand          59711 non-null  object
#  7   url            59711 non-null  object
#  8   sap            59711 non-null  float64
#  9   cat1           11544 non-null  object
#  10  cat2           11544 non-null  object
#  11  cat3           11544 non-null  object
#  12  cat4           11544 non-null  object
#  13  cat5           11544 non-null  object
#  14  cat6           11544 non-null  object
#  15  sales          59711 non-null  float64
#  16  units_sold     59711 non-null  int64
# ...

# %%
df_2019.head()
# Out:
#          date channel country             shop_name                     sku  \
# 0  2019-01-01  Lazada      PH  Lazada Retail Lactum  260013061_PH-358536442
# 1  2019-01-01  Lazada      PH  Lazada Retail Lactum  267657810_PH-379353311
# 2  2019-01-01  Lazada      PH  Lazada Retail Lactum  267665603_PH-379348476
# 3  2019-01-01  Lazada      PH  Lazada Retail Lactum  267669546_PH-379343854
# 4  2019-01-01  Lazada      PH  Lazada Retail Lactum                  DELETE
#
#                                         product_name   brand  \
# 0            Lactum 3+ Plain Powdered Milk Drink 2kg  Lactum
# 1  Lactum 3+ Plain Powdered Milk Drink 1.6Kg with...  Lactum
# 2  Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...  Lactum
# 3           Lactum 3+ Plain Powdered Milk Drink 150g  Lactum
# 4  2 Packs Of Lactum 3+ Plain Powdered Milk Drink...  Lactum
#
#                                                  url        sap cat1  ...  \
# ...

# %%
df_2019.head()
# Out:
#          date channel country             shop_name                     sku  \
# 0  2019-01-01  Lazada      PH  Lazada Retail Lactum  260013061_PH-358536442
# 1  2019-01-01  Lazada      PH  Lazada Retail Lactum  267657810_PH-379353311
# 2  2019-01-01  Lazada      PH  Lazada Retail Lactum  267665603_PH-379348476
# 3  2019-01-01  Lazada      PH  Lazada Retail Lactum  267669546_PH-379343854
# 4  2019-01-01  Lazada      PH  Lazada Retail Lactum                  DELETE
#
#                                         product_name   brand  \
# 0            Lactum 3+ Plain Powdered Milk Drink 2kg  Lactum
# 1  Lactum 3+ Plain Powdered Milk Drink 1.6Kg with...  Lactum
# 2  Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...  Lactum
# 3           Lactum 3+ Plain Powdered Milk Drink 150g  Lactum
# 4  2 Packs Of Lactum 3+ Plain Powdered Milk Drink...  Lactum
#
#                                                  url        sap cat1  ...  \
# ...

# %%
df_2020.head()
# Out:
#        date channel country             shop_name                     sku  \
# 0  1/1/2020  Lazada      PH  Lazada Retail Lactum  260035300_PH-358552297
# 1  1/1/2020  Lazada      PH  Lazada Retail Lactum  267665603_PH-379348476
# 2  1/1/2020  Lazada      PH  Lazada Retail Lactum  267669546_PH-379343854
# 3  1/1/2020  Lazada      PH  Lazada Retail Lactum  289354401_PH-466924139
# 4  1/1/2020  Lazada      PH  Lazada Retail Lactum  289378542_PH-466926524
#
#                                         product_name   brand  \
# 0                     Lactum for 1-3 Years Old 1.2kg  Lactum
# 1  Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...  Lactum
# 2                               Lactum 3+ Plain 150g  Lactum
# 3                        Lactum for 6+ years old 2kg  Lactum
# 4                     Lactum for 1-3 Years Old 2.4kg  Lactum
#
#                                                  url        sap cat1  ...  \
# 0  https://www.lazada.com.ph/products/-i260035300...  2046791.0  NaN  ...
# ...

# %%
# df.Month.map("{:02}".format)

# %%
df_2020.date = df_2020.date.apply(lambda x: x.split('/')[2]+'-'+x.split('/')[0].zfill(2)+'-'+x.split('/')[1].zfill(2))

# %%
# Out:
#              date channel country               shop_name  \
# 0      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 1      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 2      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 3      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 4      2020-01-01  Lazada      PH    Lazada Retail Lactum
# ...           ...     ...     ...                     ...
# 59706  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 59707  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 59708  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 59709  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 59710  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
#
#                             sku  \
# 0        260035300_PH-358552297
# 1        267665603_PH-379348476
# 2        267669546_PH-379343854
# 3        289354401_PH-466924139
# 4        289378542_PH-466926524
# ...                         ...
# 59706    298062323_PH-508740875
# ...

# %%
df = pd.concat([df_2019, df_2020])

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#              date channel country               shop_name  \
# 0      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 1      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 2      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 3      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 4      2019-01-01  Lazada      PH    Lazada Retail Lactum
# ...           ...     ...     ...                     ...
# 93002  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 93003  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 93004  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 93005  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
# 93006  2020-12-31  Lazada     NaN  Lazada Retail Sustagen
#
#                             sku  \
# 0        260013061_PH-358536442
# 1        267657810_PH-379353311
# 2        267665603_PH-379348476
# 3        267669546_PH-379343854
# 4                        DELETE
# ...                         ...
# 93002    298062323_PH-508740875
# ...

# %%
df.to_csv('BA_Final.csv', index=False)

# %%
df.sort_index(inplace=True)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv('BA.csv', index=False)

# %%
df.tp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93007 entries, 0 to 93006
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           93007 non-null  datetime64[ns]
#  1   channel        93007 non-null  object
#  2   country        79229 non-null  object
#  3   shop_name      93007 non-null  object
#  4   sku            93007 non-null  object
#  5   product_name   93007 non-null  object
#  6   brand          93007 non-null  object
#  7   url            93007 non-null  object
#  8   sap            93007 non-null  float64
#  9   cat1           18646 non-null  object
#  10  cat2           18646 non-null  object
#  11  cat3           18646 non-null  object
#  12  cat4           18646 non-null  object
#  13  cat5           18646 non-null  object
#  14  cat6           18646 non-null  object
#  15  sales          93007 non-null  float64
#  16  units_sold     93007 non-null  int64
# ...

# %%
df.to_csv('BA_clean.csv', index=False)

# %%
df_2020.date = df_2020.date.apply(lambda x: x.split('/')[2]+'-'+x.split('/')[0]+'-'+x.split('/')[1])

# %%
df_2020.date.unique()
# Out:
# array(['2020-1-1', '2020-1-2', '2020-1-3', '2020-1-4', '2020-1-5',
#        '2020-1-6', '2020-1-7', '2020-1-8', '2020-1-9', '2020-1-10',
#        '2020-1-11', '2020-1-12', '2020-1-13', '2020-1-14', '2020-1-15',
#        '2020-1-16', '2020-1-17', '2020-1-18', '2020-1-19', '2020-1-20',
#        '2020-1-21', '2020-1-22', '2020-1-23', '2020-1-24', '2020-1-25',
#        '2020-1-26', '2020-1-27', '2020-1-28', '2020-1-29', '2020-1-30',
#        '2020-1-31', '2020-2-1', '2020-2-2', '2020-2-3', '2020-2-4',
#        '2020-2-5', '2020-2-6', '2020-2-7', '2020-2-8', '2020-2-9',
#        '2020-2-10', '2020-2-11', '2020-2-12', '2020-2-13', '2020-2-14',
#        '2020-2-15', '2020-2-16', '2020-2-17', '2020-2-18', '2020-2-19',
#        '2020-2-20', '2020-2-21', '2020-2-22', '2020-2-23', '2020-2-24',
#        '2020-2-25', '2020-2-26', '2020-2-27', '2020-2-28', '2020-2-29',
#        '2020-3-1', '2020-3-2', '2020-3-3', '2020-3-4', '2020-3-5',
# ...

# %%
df_2020.loc[df_2020['channel']=='PH']['country'] = df_2020.loc[df_2020['channel']=='PH']['channel'].values
# Out:
# <ipython-input-156-abccace780b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020.loc[df_2020['channel']=='PH']['country'] = df_2020.loc[df_2020['channel']=='PH']['channel'].values

# %%
df_2020['country']=df_2020.country.fillna('PH')

# %%
df_2020.loc[df_2020['channel']=='PH']['channel'] = df_2020.loc[df_2020['channel']=='PH'].url.str.contains('lazada')
# Out:
# <ipython-input-193-1893c3295913>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020.loc[df_2020['channel']=='PH']['channel'] = df_2020.loc[df_2020['channel']=='PH'].url.str.contains('lazada')

# %%
df_2020.loc[df_2020['channel']=='PH']['channel'] = df_2020.loc[df_2020['channel']=='PH']['url']
# Out:
# <ipython-input-200-7c87f5b70e58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020.loc[df_2020['channel']=='PH']['channel'] = df_2020.loc[df_2020['channel']=='PH']['url']

# %%
df_2020.loc[df_2020['channel']=='PH'].channel = 'Shopee'
# Out:
# /home/msds2021/mromero/.local/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_2020['channel'] = df_2020.url.str.contains('laz')

# %%
def replacer(x):
    if x == True:
        return 'Lazada'
    else:
        return 'Shopee'

# %%
df_2020['channel']=df_2020.channel.apply(lambda x: replacer(x))

# %%
df_2020
# Out:
#              date channel country               shop_name  \
# 0      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 1      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 2      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 3      2020-01-01  Lazada      PH    Lazada Retail Lactum
# 4      2020-01-01  Lazada      PH    Lazada Retail Lactum
# ...           ...     ...     ...                     ...
# 59706  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59707  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59708  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59709  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59710  2020-12-31  Lazada      PH  Lazada Retail Sustagen
#
#                             sku  \
# 0        260035300_PH-358552297
# 1        267665603_PH-379348476
# 2        267669546_PH-379343854
# 3        289354401_PH-466924139
# 4        289378542_PH-466926524
# ...                         ...
# 59706    298062323_PH-508740875
# ...

# %%
df = pd.concat([df_2019, df_2020])

# %%
df
# Out:
#              date channel country               shop_name  \
# 0      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 1      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 2      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 3      2019-01-01  Lazada      PH    Lazada Retail Lactum
# 4      2019-01-01  Lazada      PH    Lazada Retail Lactum
# ...           ...     ...     ...                     ...
# 59706  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59707  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59708  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59709  2020-12-31  Lazada      PH  Lazada Retail Sustagen
# 59710  2020-12-31  Lazada      PH  Lazada Retail Sustagen
#
#                             sku  \
# 0        260013061_PH-358536442
# 1        267657810_PH-379353311
# 2        267665603_PH-379348476
# 3        267669546_PH-379343854
# 4                        DELETE
# ...                         ...
# 59706    298062323_PH-508740875
# ...

# %%
df[df['brand'] == 'Sustagen']
# Out:
#             date channel country                shop_name         sku  \
# 64    2019-01-01  Lazada      PH   Lazada Retail Sustagen      DELETE
# 65    2019-01-01  Lazada      PH   Lazada Retail Sustagen      DELETE
# 136   2019-01-02  Lazada      PH   Lazada Retail Sustagen      DELETE
# 137   2019-01-02  Lazada      PH   Lazada Retail Sustagen      DELETE
# 211   2019-01-03  Lazada      PH   Lazada Retail Sustagen      DELETE
# ...          ...     ...     ...                      ...         ...
# 89029 2020-12-31  Shopee      PH  sustagenofficialstoreph  4153753299
# 89030 2020-12-31  Shopee      PH  sustagenofficialstoreph  3350811017
# 89031 2020-12-31  Shopee      PH  sustagenofficialstoreph  6550714086
# 89032 2020-12-31  Shopee      PH  sustagenofficialstoreph  4052474559
# 89033 2020-12-31  Shopee      PH  sustagenofficialstoreph  3853850249
#
#                                             product_name     brand  \
# ...

# %% [markdown]
# 1. Lazada, Shoppee Comparison
# - number of transactions
# - dominant brand per channel (sales)
#
# 2. Top and Bottom SKU
#
# 3. per brand and sku
# - click rate
# - units sold
# - product views
# - sales
