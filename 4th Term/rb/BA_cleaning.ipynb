# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import regex

# %% [markdown]
# ### Cleaning BA2019 data
# The algorithms below execute an automated process for cleaning the BA Data.

# %%
def BA_cleaning():
    '''Function to clean BA data'''
    
    # Store directories in variables
    rb_dir = '/mnt/processed/private/msds2021/cpt6/rb-datasets/'
    BA_2019 = os.path.join(rb_dir, 'BA 2019.csv')
    
    # Loading to dataframes
    df_BA2019 = pd.read_csv(BA_2019, engine='python')
    
    # Dropping unnecessary column
    df_BA2019 = df_BA2019.drop(['row', 'shop_id'], axis = 1)

    # Filtering the dataset by Lactum and Enfa Products
    brand_prefix = ['Lactum', 'Enfa', 'Sustagen']
    df_BA2019 = df_BA2019[df_BA2019.Brand.str.startswith(tuple(brand_prefix))]
    
    # Fixing index
    df_BA2019 = df_BA2019.reset_index(drop=True)
    
    # Renaming columns
    df_BA2019.rename(columns = {'Day of date': 'date', 
                                 'Channel': 'channel', 
                                 'Country ': 'country', 
                                 'Shop name': 'shop_name',
                                 'SKU': 'sku', 
                                 'Brand': 'brand', 
                                 'SAP': 'sap', 
                                 'Category 1': 'cat1', 
                                 'Category 2': 'cat2', 
                                 'Category 3': 'cat3', 
                                 'Category 4': 'cat4', 
                                 'Category 5': 'cat5', 
                                 'Category 6': 'cat6',
                                 'Sales' : 'sales', 
                                 'Unit Sold': 'units_sold', 
                                 'Product View': 'product_views',
                                 'CR': 'click_rate', 
                                 'Buyer': 'buyer', 
                                 'Order': 'order'}, inplace=True)

    df_BA2019['date'] = pd.to_datetime(df_BA2019['date'])
    
    return df_BA2019

# %%
df_BA2019 = BA_cleaning()

# %%
df_BA2019.brand.value_counts()
# Out:
# Lactum              15886
# Enfagrow             9132
# Enfamil              5591
# Sustagen Premium     1495
# Enfamama              767
# Sustagen              425
# Name: brand, dtype: int64

# %%
df_BA2019.columns
# Out:
# Index(['date', 'channel', 'country', 'shop_name', 'sku', 'product_name',
#        'brand', 'url', 'sap', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6',
#        'sales', 'units_sold', 'product_views', 'click_rate', 'buyer', 'order'],
#       dtype='object')

# %%
df_BA2019.channel.value_counts()
# Out:
# Lazada    25557
# Shopee     7739
# Name: channel, dtype: int64

# %%
df_BA2019.head()
# Out:
#         date channel country             shop_name                     sku  \
# 0 2019-01-01  Lazada      PH  Lazada Retail Lactum  260013061_PH-358536442
# 1 2019-01-01  Lazada      PH  Lazada Retail Lactum  267657810_PH-379353311
# 2 2019-01-01  Lazada      PH  Lazada Retail Lactum  267665603_PH-379348476
# 3 2019-01-01  Lazada      PH  Lazada Retail Lactum  267669546_PH-379343854
# 4 2019-01-01  Lazada      PH  Lazada Retail Lactum                  DELETE
#
#                                         product_name   brand  \
# 0            Lactum 3+ Plain Powdered Milk Drink 2kg  Lactum
# 1  Lactum 3+ Plain Powdered Milk Drink 1.6Kg with...  Lactum
# 2  Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...  Lactum
# 3           Lactum 3+ Plain Powdered Milk Drink 150g  Lactum
# 4  2 Packs Of Lactum 3+ Plain Powdered Milk Drink...  Lactum
#
#                                                  url        sap cat1  ...  \
# 0  https://www.lazada.com.ph/products/-i260013061...  2048174.0  NaN  ...
# 1  https://www.lazada.com.ph/products/-i267657810...        NaN  NaN  ...
# 2  https://www.lazada.com.ph/products/-i267665603...        NaN  NaN  ...
# 3  https://www.lazada.com.ph/products/-i267669546...  2020877.0  NaN  ...
# 4  https://www.lazada.com.ph/products/-i267671509...        NaN  NaN  ...
#
#   cat3 cat4 cat5 cat6 sales units_sold product_views click_rate buyer order
# 0  NaN  NaN  NaN  NaN   $0           0            25      0.00%     0     0
# 1  NaN  NaN  NaN  NaN   $0          10           116      8.62%    10    10
# 2  NaN  NaN  NaN  NaN   $0           1            27      3.70%     1     1
# 3  NaN  NaN  NaN  NaN   $0           0            62      0.00%     0     0
# 4  NaN  NaN  NaN  NaN   $0          17           298      5.70%    14    14
#
# [5 rows x 21 columns]

# %%
d = df_BA2019

# %%
df_BA2019.product_name.str.split(r'^$(Lactum|Enfagrow).*[^A-Za-z]\b')
# Out:
# 0                [Lactum 3+ Plain Powdered Milk Drink 2kg]
# 1        [Lactum 3+ Plain Powdered Milk Drink 1.6Kg wit...
# 2        [Lactum 3+ Plain Powdered Milk Drink 1.2Kg wit...
# 3               [Lactum 3+ Plain Powdered Milk Drink 150g]
# 4        [2 Packs Of Lactum 3+ Plain Powdered Milk Drin...
#                                ...
# 31371    [Lactum 3+ Plain Powdered Milk Drink 1.2kg w/ ...
# 31372    [Lactum 3+ Plain Powdered Milk Drink 1.6kg w/ ...
# 31373    [Lactum Milk Supplement Powder for 1-3 Years O...
# 31374    [Lactum 3+ Plain Powdered Milk Drink 3.2kg Twi...
# 31375    [Lactum 3+ Plain 1.2kg Buy 1 Take Lactum 3+ Pl...
# Name: product_name, Length: 31376, dtype: object

# %%
df_BA2019['sap'] = df_BA2019.sap.fillna(0)

df_BA2019['cat1'] = df_BA2019.cat1.fillna('')
df_BA2019['cat2'] = df_BA2019.cat2.fillna('')
df_BA2019['cat3'] = df_BA2019.cat3.fillna('')
df_BA2019['cat4'] = df_BA2019.cat4.fillna('')
df_BA2019['cat5'] = df_BA2019.cat5.fillna('')
df_BA2019['cat6'] = df_BA2019.cat6.fillna('')

df_BA2019['sales'] = (df_BA2019['sales']
                      .str.replace(',', '').str.replace('$', '').astype(int))

df_BA2019['units_sold'] = (df_BA2019['units_sold']
                      .str.replace(',', '').str.replace('$', '').astype(int))

df_BA2019['product_views'] = (df_BA2019['product_views']
                      .str.replace(',', '').str.replace('$', '').astype(int))

df_BA2019['click_rate'] = df_BA2019.click_rate.str[:-1].astype(float)

df_BA2019['buyer'] = (df_BA2019['buyer']
                      .str.replace(',', '').str.replace('$', '').astype(int))

df_BA2019['order'] = (df_BA2019['order']
                      .str.replace(',', '').str.replace('$', '').astype(int))

# %%
df_BA2019.to_csv('BA_2019_clean.csv', index=False)

# %%
pd.read_csv('BA_2019_clean.csv')
# Out:
#              date channel country              shop_name  \
# 0      2019-01-01  Lazada      PH   Lazada Retail Lactum
# 1      2019-01-01  Lazada      PH   Lazada Retail Lactum
# 2      2019-01-01  Lazada      PH   Lazada Retail Lactum
# 3      2019-01-01  Lazada      PH   Lazada Retail Lactum
# 4      2019-01-01  Lazada      PH   Lazada Retail Lactum
# ...           ...     ...     ...                    ...
# 33291  2019-12-31  Shopee      PH  Lactum Official Store
# 33292  2019-12-31  Shopee      PH  Lactum Official Store
# 33293  2019-12-31  Shopee      PH  Lactum Official Store
# 33294  2019-12-31  Shopee      PH  Lactum Official Store
# 33295  2019-12-31  Shopee      PH  Lactum Official Store
#
#                           sku  \
# 0      260013061_PH-358536442
# 1      267657810_PH-379353311
# 2      267665603_PH-379348476
# 3      267669546_PH-379343854
# 4                      DELETE
# ...                       ...
# 33291              1694625455
# 33292              1694625681
# 33293              2050315224
# 33294              2172469378
# 33295              2764740073
#
#                                             product_name   brand  \
# 0                Lactum 3+ Plain Powdered Milk Drink 2kg  Lactum
# 1      Lactum 3+ Plain Powdered Milk Drink 1.6Kg with...  Lactum
# 2      Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...  Lactum
# 3               Lactum 3+ Plain Powdered Milk Drink 150g  Lactum
# 4      2 Packs Of Lactum 3+ Plain Powdered Milk Drink...  Lactum
# ...                                                  ...     ...
# 33291  Lactum 3+ Plain Powdered Milk Drink 1.2kg w/ F...  Lactum
# 33292  Lactum 3+ Plain Powdered Milk Drink 1.6kg w/ F...  Lactum
# 33293  Lactum Milk Supplement Powder for 1-3 Years Ol...  Lactum
# 33294  Lactum 3+ Plain Powdered Milk Drink 3.2kg Twin...  Lactum
# 33295  Lactum 3+ Plain 1.2kg Buy 1 Take Lactum 3+ Pla...  Lactum
#
#                                                      url        sap  \
# 0      https://www.lazada.com.ph/products/-i260013061...  2048174.0
# 1      https://www.lazada.com.ph/products/-i267657810...        0.0
# 2      https://www.lazada.com.ph/products/-i267665603...        0.0
# 3      https://www.lazada.com.ph/products/-i267669546...  2020877.0
# 4      https://www.lazada.com.ph/products/-i267671509...        0.0
# ...                                                  ...        ...
# 33291  https://shopee.ph/Lactum-3-Plain-Powdered-Milk...  2046795.0
# 33292  https://shopee.ph/Lactum-3-Plain-Powdered-Milk...  2048491.0
# 33293  https://shopee.ph/Lactum-Milk-Supplement-Powde...  2052197.0
# 33294  https://shopee.ph/Lactum-3-Plain-Powdered-Milk...  2052601.0
# 33295  https://shopee.ph/Lactum-3-Plain-1.2kg-Buy-1-T...  2046795.0
#
#             cat1  ...     cat3         cat4     cat5       cat6 sales  \
# 0            NaN  ...      NaN          NaN      NaN        NaN     0
# 1            NaN  ...      NaN          NaN      NaN        NaN     0
# 2            NaN  ...      NaN          NaN      NaN        NaN     0
# 3            NaN  ...      NaN          NaN      NaN        NaN     0
# 4            NaN  ...      NaN          NaN      NaN        NaN     0
# ...          ...  ...      ...          ...      ...        ...   ...
# 33291         3+  ...  Stage 4  Medium Pack      GWP  Nutrition    13
# 33292         3+  ...  Stage 4  Medium Pack      GWP  Nutrition    32
# 33293  1-3 Years  ...  Stage 3  Medium Pack  Singles  Nutrition    41
# 33294         3+  ...  Stage 4     Big Pack  Singles  Nutrition    23
# 33295         3+  ...  Stage 4  Medium Pack      GWP  Nutrition    11
#
#        units_sold  product_views  click_rate  buyer  order
# 0               0             25        0.00      0      0
# 1              10            116        8.62     10     10
# 2               1             27        3.70      1      1
# 3               0             62        0.00      0      0
# 4              17            298        5.70     14     14
# ...           ...            ...         ...    ...    ...
# 33291           1              0        0.00      1      1
# 33292           2              0        0.00      1      1
# 33293           2              0        0.00      1      1
# 33294           1              0        0.00      1      1
# 33295           1              0        0.00      1      1
#
# [33296 rows x 21 columns]

# %% [markdown]
# ## Cleaning BA2020

# %%
# Store directories in variables
rb_dir = '/mnt/processed/private/msds2021/cpt6/rb-datasets/'
BA_2020 = os.path.join(rb_dir, 'BA 2020.csv')

df_BA2020 = pd.read_csv(BA_2020, sep='\t', encoding = 'utf-16')

# Filtering the dataset by Lactum and Enfa Products
brand_prefix = ['Lactum', 'Enfa', 'Sustagen']
df_BA2020 = df_BA2020[df_BA2020.Brand.str.startswith(tuple(brand_prefix))]

df_BA2020 = df_BA2020.reset_index(drop=True)

df2 = df_BA2020[45933:]
df1 = df_BA2020[:45933]

# %%
df2.columns
# Out:
# Index(['row', 'Day of date', 'Channel', 'Country ', 'shop_id', 'Shop name',
#        'SKU', 'product_name', 'Brand', 'url', 'SAP', 'Category 1',
#        'Category 2', 'Category 3', 'Category 4', 'Category 5', 'Category 6',
#        'Sales', 'Unit Sold', 'Product View', 'CR', 'Buyer', 'Order'],
#       dtype='object')

# %%
df2.rename(columns = {'Channel' : 'shop_id', 
                      'shop_id': 'Country'}, inplace=True)
# Out:
# /home/msds2021/mromero/.local/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df2.rename(columns = {'Country ': 'Channel'}, inplace = True)

# %%
df2 = df2[['row', 'Day of date', 'Channel', 'Country', 'shop_id', 'Shop name',
       'SKU', 'product_name', 'Brand', 'url', 'SAP', 'Category 1',
       'Category 2', 'Category 3', 'Category 4', 'Category 5', 'Category 6',
       'Sales', 'Unit Sold', 'Product View', 'CR', 'Buyer', 'Order']]

# %%
df1.rename(columns={'Country': 'Country '}, inplace=True)

# %%
BA_2020 = pd.concat([df1, df2], ignore_index=True)

# %%
df_BA2020 = BA_2020

# %%
df_BA2020.rename(columns = {'Day of date': 'date', 
                             'Channel': 'channel', 
                             'Country ': 'country', 
                             'Shop name': 'shop_name',
                             'SKU': 'sku', 
                             'Brand': 'brand', 
                             'SAP': 'sap', 
                             'Category 1': 'cat1', 
                             'Category 2': 'cat2', 
                             'Category 3': 'cat3', 
                             'Category 4': 'cat4', 
                             'Category 5': 'cat5', 
                             'Category 6': 'cat6',
                             'Sales' : 'sales', 
                             'Unit Sold': 'units_sold', 
                             'Product View': 'product_views',
                             'CR': 'click_rate', 
                             'Buyer': 'buyer', 
                             'Order': 'order'}, inplace=True)

# %%
df_BA2020['sap'] = df_BA2020.sap.fillna(0)

df_BA2020['cat1'] = df_BA2020.cat1.fillna('')
df_BA2020['cat2'] = df_BA2020.cat2.fillna('')
df_BA2020['cat3'] = df_BA2020.cat3.fillna('')
df_BA2020['cat4'] = df_BA2020.cat4.fillna('')
df_BA2020['cat5'] = df_BA2020.cat5.fillna('')
df_BA2020['cat6'] = df_BA2020.cat6.fillna('')

# %%
df_BA2020
# Out:
#            row        date channel country shop_id               shop_name  \
# 0           59    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 1           60    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 2           61    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 3           62    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 4           63    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# ...        ...         ...     ...     ...     ...                     ...
# 59706  146,324  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59707  146,325  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59708  146,326  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59709  146,327  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59710  146,328  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
#
#                             sku  \
# 0        260035300_PH-358552297
# 1        267665603_PH-379348476
# 2        267669546_PH-379343854
# 3        289354401_PH-466924139
# 4        289378542_PH-466926524
# ...                         ...
# 59706    298062323_PH-508740875
# 59707    298062315_PH-508738075
# 59708    298058375_PH-508722170
# 59709  1286610071_PH-4668890342
# 59710  1286566715_PH-4668888683
#
#                                             product_name             brand  \
# 0                         Lactum for 1-3 Years Old 1.2kg            Lactum
# 1      Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...            Lactum
# 2                                   Lactum 3+ Plain 150g            Lactum
# 3                            Lactum for 6+ years old 2kg            Lactum
# 4                         Lactum for 1-3 Years Old 2.4kg            Lactum
# ...                                                  ...               ...
# 59706  Sustagen Premium Chocolate Adult Nutritional B...  Sustagen Premium
# 59707   Sustagen Premium Adult Nutritional Beverage 350g  Sustagen Premium
# 59708   Sustagen Premium Adult Nutritional Beverage 900g  Sustagen Premium
# 59709  Sustagen Premium 9.6kg Adult Nutritional Bever...  Sustagen Premium
# 59710  Sustagen Premium 5.4kg Adult Nutritional Bever...  Sustagen Premium
#
#                                                      url  ...  cat4 cat5 cat6  \
# 0      https://www.lazada.com.ph/products/-i260035300...  ...
# 1      https://www.lazada.com.ph/products/-i267665603...  ...
# 2      https://www.lazada.com.ph/products/-i267669546...  ...
# 3      https://www.lazada.com.ph/products/-i289354401...  ...
# 4      https://www.lazada.com.ph/products/-i289378542...  ...
# ...                                                  ...  ...   ...  ...  ...
# 59706  https://www.lazada.com.ph/products/i298062323-...  ...
# 59707  https://www.lazada.com.ph/products/i298062315-...  ...
# 59708  https://www.lazada.com.ph/products/i298058375-...  ...
# 59709  https://www.lazada.com.ph/products/i1286610071...  ...
# 59710  https://www.lazada.com.ph/products/i1286566715...  ...
#
#        sales units_sold product_views click_rate buyer order Country
# 0       $12           1            26      3.85%     1     1     NaN
# 1        $0           0            14      0.00%     0     0     NaN
# 2        $0           5            10     50.00%     1     1     NaN
# 3       $17           1            35      2.86%     1     1     NaN
# 4      $138           6            70      8.57%     5     6     NaN
# ...      ...        ...           ...        ...   ...   ...     ...
# 59706      0          0            26      0.00%     0     0      PH
# 59707      0          0             4      0.00%     0     0      PH
# 59708      0          0            28      0.00%     0     0      PH
# 59709      0          0             5      0.00%     0     0      PH
# 59710      0          0             3      0.00%     0     0      PH
#
# [59711 rows x 24 columns]

# %%
df_BA2020['sales'] = (df_BA2020['sales'].str.replace(',', '').str.replace('$', ''))

# %%
df_BA2020['sales'] = df_BA2020['sales'].fillna(0)

# %%
df_BA2020['sales'] = df_BA2020['sales'].astype(float)

# %%
df_BA2020['units_sold'] = (df_BA2020['units_sold']
                      .str.replace(',', '').str.replace('$', ''))

# %%
df_BA2020['units_sold'] = df_BA2020['units_sold'].fillna(0)

# %%
df_BA2020['units_sold'] = df_BA2020['units_sold'].astype(int)

# %%
df_BA2020['product_views'] = (df_BA2020['product_views']
                      .str.replace(',', '').str.replace('$', '').fillna(0).astype(int))

# %%
df_BA2020['click_rate'] = df_BA2020.click_rate.str[:-1].astype(float)

# %%
df_BA2020['buyer'] = (df_BA2020['buyer']
                      .str.replace(',', '').str.replace('$', ''))

# %%
df_BA2020['buyer'] = df_BA2020['buyer'].fillna(0)

# %%
df_BA2020['buyer'] = df_BA2020['buyer'].astype(int)

# %%
df_BA2020['order'] = (df_BA2020['order']
                      .str.replace(',', '').str.replace('$', ''))

# %%
df_BA2020['order'] = df_BA2020['order'].fillna(0).astype(int)

# %%
df_BA2020
# Out:
#            row        date channel country shop_id               shop_name  \
# 0           59    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 1           60    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 2           61    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 3           62    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# 4           63    1/1/2020  Lazada      PH    3297    Lazada Retail Lactum
# ...        ...         ...     ...     ...     ...                     ...
# 59706  146,324  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59707  146,325  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59708  146,326  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59709  146,327  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
# 59710  146,328  12/31/2020  Lazada     NaN      12  Lazada Retail Sustagen
#
#                             sku  \
# 0        260035300_PH-358552297
# 1        267665603_PH-379348476
# 2        267669546_PH-379343854
# 3        289354401_PH-466924139
# 4        289378542_PH-466926524
# ...                         ...
# 59706    298062323_PH-508740875
# 59707    298062315_PH-508738075
# 59708    298058375_PH-508722170
# 59709  1286610071_PH-4668890342
# 59710  1286566715_PH-4668888683
#
#                                             product_name             brand  \
# 0                         Lactum for 1-3 Years Old 1.2kg            Lactum
# 1      Lactum 3+ Plain Powdered Milk Drink 1.2Kg with...            Lactum
# 2                                   Lactum 3+ Plain 150g            Lactum
# 3                            Lactum for 6+ years old 2kg            Lactum
# 4                         Lactum for 1-3 Years Old 2.4kg            Lactum
# ...                                                  ...               ...
# 59706  Sustagen Premium Chocolate Adult Nutritional B...  Sustagen Premium
# 59707   Sustagen Premium Adult Nutritional Beverage 350g  Sustagen Premium
# 59708   Sustagen Premium Adult Nutritional Beverage 900g  Sustagen Premium
# 59709  Sustagen Premium 9.6kg Adult Nutritional Bever...  Sustagen Premium
# 59710  Sustagen Premium 5.4kg Adult Nutritional Bever...  Sustagen Premium
#
#                                                      url  ...  cat4 cat5 cat6  \
# 0      https://www.lazada.com.ph/products/-i260035300...  ...
# 1      https://www.lazada.com.ph/products/-i267665603...  ...
# 2      https://www.lazada.com.ph/products/-i267669546...  ...
# 3      https://www.lazada.com.ph/products/-i289354401...  ...
# 4      https://www.lazada.com.ph/products/-i289378542...  ...
# ...                                                  ...  ...   ...  ...  ...
# 59706  https://www.lazada.com.ph/products/i298062323-...  ...
# 59707  https://www.lazada.com.ph/products/i298062315-...  ...
# 59708  https://www.lazada.com.ph/products/i298058375-...  ...
# 59709  https://www.lazada.com.ph/products/i1286610071...  ...
# 59710  https://www.lazada.com.ph/products/i1286566715...  ...
#
#        sales units_sold product_views click_rate  buyer  order  Country
# 0       12.0          1            26       3.85      0      0      NaN
# 1        0.0          0            14       0.00      0      0      NaN
# 2        0.0          5            10      50.00      0      0      NaN
# 3       17.0          1            35       2.86      0      0      NaN
# 4      138.0          6            70       8.57      0      0      NaN
# ...      ...        ...           ...        ...    ...    ...      ...
# 59706    0.0          0             0       0.00      0      0       PH
# 59707    0.0          0             0       0.00      0      0       PH
# 59708    0.0          0             0       0.00      0      0       PH
# 59709    0.0          0             0       0.00      0      0       PH
# 59710    0.0          0             0       0.00      0      0       PH
#
# [59711 rows x 24 columns]

# %%
df_BA2020.to_csv('BA_2020_clean.csv', index=False)

# %% [markdown]
# Update Meeting 1
#
# 1. Greetings
# 2. Update
# - Data cleaning - done
# - questions about the data
# 3. Next steps
# - EDA
# - Business Context
# - Modelling
# 4. Other Concerns
# - Laptop
# - Next Tuesday
