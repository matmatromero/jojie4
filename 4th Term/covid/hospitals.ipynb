# %%
import pandas as pd
import numpy as np

# %%
df_hosp = pd.read_csv('hospitals.csv')

# %%
df_hosp.head()
# Out:
#      id                           cfname                           namefaci  \
# 0  1427       RODOLFO MORALES MED. CLIN.     RODOLFO MORALES MEDICAL CLINIC
# 1  1074       BASILAN COMMUNITY HOSPITAL   BASILAN COMMUNITY HOSPITAL, INC.
# 2   195       AMAI PAKPAK MEDICAL CENTER         AMAI PAKPAK MEDICAL CENTER
# 3   952        CATUBIG DISTRICT HOSPITAL          CATUBIG DISTRICT HOSPITAL
# 4   415  QUIRINO PROVINCE MEDICAL CENTER  QUIRINO PROVINCIAL MEDICAL CENTER
#
#                                         region  region_psgc  \
# 0                     REGION XI (DAVAO REGION)  PH110000000
# 1              REGION IX (ZAMBOANGA PENINSULA)  PH090000000
# 2  AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)  PH150000000
# 3                REGION VIII (EASTERN VISAYAS)  PH080000000
# 4                   REGION II (CAGAYAN VALLEY)  PH020000000
#
#                            province province_psgc               city_mun  \
# ...

# %%
df_hosp.columns
# Out:
# Index(['id', 'cfname', 'namefaci', 'region', 'region_psgc', 'province',
#        'province_psgc', 'city_mun', 'city_mun_psgc', 'north_coord',
#        'east_coord', 'updateddate', 'addeddate', 'reportdate', 'ambulance',
#        'icu_np', 'ics_total', 'support_total', 'radtech_total',
#        'respthe_total', 'nurse_total', 'resdoc_total', 'medtech_total',
#        'Augmen_total', 'support_triage', 'nurse_triage', 'resdoc_triage',
#        'support_icu', 'respthe_icu', 'nurse_icu', 'resdoc_icu', 'ics_icu',
#        'support_ward', 'radtech_ward', 'respthe_ward', 'medtech_ward',
#        'nurse_ward', 'resdoc_ward', 'ics_ward', 'ics_er', 'nurse_er',
#        'radtech_er', 'resdoc_er', 'support_er', 'medtech_er', 'respthe_er'],
#       dtype='object')

# %%
df_hosp['region'].unique()
# Out:
# array(['REGION XI (DAVAO REGION)', 'REGION IX (ZAMBOANGA PENINSULA)',
#        'AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)',
#        'REGION VIII (EASTERN VISAYAS)', 'REGION II (CAGAYAN VALLEY)',
#        'CORDILLERA ADMINISTRA TIVE REGION (CAR)',
#        'REGION XII (SOCCSKSA RGEN)', 'REGION IV-B (MIMAROPA)',
#        'REGION III (CENTRAL LUZON)', 'REGION XIII (CARAGA)',
#        'REGION VI (WESTERN VISAYAS)', 'REGION X (NORTHERN MINDANAO)', nan,
#        'REGION VII (CENTRAL VISAYAS)', 'REGION I (ILOCOS REGION)',
#        'REGION IV-A (CALABAR ZON)', 'REGION V (BICOL REGION)',
#        'NATIONAL CAPITAL REGION (NCR)'], dtype=object)

# %%
df_hosp.groupby('region').sum()
# Out:
#                                                  id  north_coord  \
# region
# AUTONOMOUS REGION IN MUSLIM MINDANAO (ARMM)   19590    46.187970
# CORDILLERA ADMINISTRA TIVE REGION (CAR)       91512   943.271471
# NATIONAL CAPITAL REGION (NCR)                178457  2088.469208
# REGION I (ILOCOS REGION)                      60556  1892.330414
# REGION II (CAGAYAN VALLEY)                    38426  1609.290152
# REGION III (CENTRAL LUZON)                   197305  2703.618688
# REGION IV-A (CALABAR ZON)                    284609  2943.097336
# REGION IV-B (MIMAROPA)                        24796   795.344354
# REGION IX (ZAMBOANGA PENINSULA)               56529   451.431167
# REGION V (BICOL REGION)                       59682  1414.155894
# REGION VI (WESTERN VISAYAS)                   79090  1042.127733
# REGION VII (CENTRAL VISAYAS)                  89872   945.395143
# REGION VIII (EASTERN VISAYAS)                 53808   663.531024
# ...
